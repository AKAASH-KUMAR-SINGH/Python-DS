# %% [markdown]
# # Mathplotlib Data Visualization

# %%
# Using matplotlib library to visualize data with
# plot and graph .
# it's an open source library

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
new_data=np.arange(9)

# %%
matplotlib notebook

# %%
matplotlib inline

# %%
plt.plot(new_data)
plt.title("the new data graph")
plt.show()

# %%
plt.plot(new_data,marker='*')

# %%
plt.plot(new_data,'o:r')
plt.title("the new data graph")
plt.show()

# %%
plt.plot(new_data,"o:b",ms=10,mfc='g',ls='-.',c='g')
plt.title("the new data graph")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_9952\4189308242.py:1: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o:b" (-> linestyle=':'). The keyword argument will take precedence.
#   plt.plot(new_data,"o:b",ms=10,mfc='g',ls='-.',c='g')
# C:\Users\akash\AppData\Local\Temp\ipykernel_9952\4189308242.py:1: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "o:b" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(new_data,"o:b",ms=10,mfc='g',ls='-.',c='g')

# %%
x=[1,2,3,4,5,6,7]
y=[1,4,9,16,25,36,49]
plt.plot(x,y,marker='D')
plt.title("The new Graph")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
data1=np.arange(2,7,0.2)
plt.plot(data1,data1,'r:',data1,data1**2,'r--',data1,data1**3,'g-.')
plt.show()

# %%
plt.savefig('newVisualization.png')

# %%
new_files=['film1','film2','film3','film4']
awards=[3,4,2,6]
plt.bar(range(len(new_files)),awards)
plt.title("the top films")
plt.ylabel("no.of awards")
plt.show()

# %% [markdown]
# # Histogram

# %%
# Using matplotlib.pyplot to show frequency distribution
# plt.hist()

# %%
new_h=np.random.normal(150,15,230)
plt.hist(new_h)
plt.show()

# %%
x=np.array([37,27,27,17])
ch_label=['first','second','third','fourth']
plt.pie(x,labels=ch_label,explode=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# h:\Python+DS\DS\matplotlib.ipynb Cell 19 line 3
#       <a href='vscode-notebook-cell:/h%3A/Python%2BDS/DS/matplotlib.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> x=np.array([37,27,27,17])
#       <a href='vscode-notebook-cell:/h%3A/Python%2BDS/DS/matplotlib.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> ch_label=['first','second','third','fourth']
# ----> <a href='vscode-notebook-cell:/h%3A/Python%2BDS/DS/matplotlib.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> plt.pie(x,labels=ch_label,explode=1)
#
# File c:\Users\akash\miniconda3\Lib\site-packages\matplotlib\pyplot.py:3546, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3523 @_copy_docstring_and_deprecators(Axes.pie)
#    3524 def pie(
#    3525     x: ArrayLike,
#    (...)
#    3544     data=None,
#    3545 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3546     return gca().pie(
#    3547         x,
#    3548         explode=explode,
#    3549         labels=labels,
#    3550         colors=colors,
#    3551         autopct=autopct,
#    3552         pctdistance=pctdistance,
#    3553         shadow=shadow,
#    3554         labeldistance=labeldistance,
#    3555         startangle=startangle,
#    3556         radius=radius,
#    3557         counterclock=counterclock,
#    3558         wedgeprops=wedgeprops,
#    3559         textprops=textprops,
#    3560         center=center,
#    3561         frame=frame,
#    3562         rotatelabels=rotatelabels,
#    3563         normalize=normalize,
#    3564         hatch=hatch,
#    3565         **({"data": data} if data is not None else {}),
#    3566     )
#
# File c:\Users\akash\miniconda3\Lib\site-packages\matplotlib\__init__.py:1478, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1475 @functools.wraps(func)
#    1476 def inner(ax, *args, data=None, **kwargs):
#    1477     if data is None:
# -> 1478         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1480     bound = new_sig.bind(ax, *args, **kwargs)
#    1481     auto_label = (bound.arguments.get(label_namer)
#    1482                   or bound.kwargs.get(label_namer))
#
# File c:\Users\akash\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:3238, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3236 if len(x) != len(labels):
#    3237     raise ValueError("'label' must be of length 'x'")
# -> 3238 if len(x) != len(explode):
#    3239     raise ValueError("'explode' must be of length 'x'")
#    3240 if colors is None:
#
# TypeError: object of type 'int' has no len()
